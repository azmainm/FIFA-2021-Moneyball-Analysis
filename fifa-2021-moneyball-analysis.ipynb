# %% [markdown]
# <h1>FIFA21 Career Mode Moneyball Analysis (Prescriptive analysis)</h1>

# %% [markdown]
# <h3>This notebook is a prescriptive analysis work performed on microsoft excel. I used a dataset that contains player data from FIFA21. The objective of the project was to find the best players for a team in the UCL (career mode) with a low budget and needs some new players. The project was inspired from the movie 'Moneyball'.</h3>

# %% [markdown]
# ![84f62cb733fcf2d3004167500c3912b0586028b3-1280x720.jpg](attachment:03b4e09c-e728-400c-bd81-2010b735da3c.jpg)

# %% [markdown]
# <h3>How the task will be approached:</h3>
#
# 1. Find team with low budget in CL
#
# 2. Find players to cut-off and increase the transfer budget
#
# 3. Find positions that need new players
#
# 4. Find best players for each position within the budget (Determine metrics first)

# %% [markdown]
# **You can view the excel file from this link**
#
# https://docs.google.com/spreadsheets/d/1Gj7A98YX6zJq7xn4Kj3kdPQQtVGyvKtR/edit?usp=sharing&ouid=116267004003950645820&rtpof=true&sd=true

# %% [markdown]
# # Team Selected

# %% [markdown]
# **AC Milan Transfer Budget: £33,543,230**
#
# **Division: Serie A**
#
# **Overall: 79**
#
# **Formation: 4-2-3-1**
#
# **AC Milan seems like a good choice. They're a team with a strong foundation but are struggling due to lack of budget and strong players. But the team can be saved.**

# %% [markdown]
# # Transfer Budget and Formation

# %% [markdown]
# **Players to cut-off:**
#
# * Ibrahimovic - £9,500,000
# * A. Saelemaekers - £4,800,000
# * Kessie - £11,500,000
# * Krunic - £4,600,000
# * Kjaer - £11,000,000
#
# **This isn't confirmed yet. Depending on the players we decide to purchase, we may decide not to sell some of these players.**
#
# **But if we did cut these players off, our new transfer budget would be £74,943,230**
#
# **I want to manage with a 4-3-3 formation.**
#
# **Need new players for the first team in positions: ST, CAM, RW and CB. Purchase the attackers first, if the budget isn’t enough, you can play Tomori with Romagnoli in CB.**

# %% [markdown]
# # ST

# %% [markdown]
# **3 potential strikers found.**
#
# **Filtered by:**
#
# Price under £35000000, age <= 30, overall > 80
#
# **Players:**
#
# * Gabriel Jesus
# * Raul Jimenez
# * Ben Yedder
#
# Gabriel Jesus is much younger than the other two and has much greater potential (up to 87). Better Dribbler but Jimenez has better physicality. Ben Yedder is a slightly better finisher. Acceleration, sprint speed, agility all better for Jesus. Jimenez is best at penalties. Jesus would be a good choice for the first couple of seasons for a low budget. Maybe in seasons later better strikers can be purchased.
#
# **Gabriel Jesus Price: £34,500,000**

# %% [markdown]
# # CAM

# %% [markdown]
# **2 Potential CAM found.**
#
# **Players:**
# * Correa
# * Lemar
#
# Lemar has a potential of 85 and Correa has 84. But, overall Correa is a better player, with more speed and attacking abilities. So, Correa would be the better choice.
#
# **Joaquin Correa: £22,500,000**

# %% [markdown]
# # RW

# %% [markdown]
# **2 Potential RM/RW found:**
# * Cuadrado
# * Suso
#
# Both have the same potential, Cuadrado is a little older though. Cuadrado has much better dribbling ability but Suso is a better passer. Pretty similar so Cuadrado would be a better choice as he is very cheap and if we purchase him, we won’t have to sell Saelemaekers.
#
# **Cuadrado: £11,000,000**

# %% [markdown]
# # Final Remarks
#
#
# **As we don't have to sell Saelemaekers, our new transfer budget stands at £70,143,230 and after the purchases, £2,143,230 is remaining and this can be alloted for wages**
#
# **Tonali has great potential so can be sent on loan if not played enough.**
#
# **Tomori can be played with Romagnoli in CB.**
#
# **Although the players selected for purchase may not be the best, we have to keep in mind that the transfer budget is very low and we can't just cut-off any player. These players should help the team advance far in the championships and if transfer budget increases next seasons, better players can be purchased.**
